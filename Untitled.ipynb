# %%
import sys
import os
import numpy as np
from matplotlib import pyplot as plt

# %%
d_max = np.array([ 0.07, -0.01 , 0.05, 0.13, 0.13, 0.17, 0.21])
phi_max = np.array([ 0.1 , 0.1, -0.4 ,-0.4, -0.8 , -1.1, -1.2])
line = np.polyfit(phi_max, d_max,1)
line
p = np.poly1d(line)

xp = np.linspace(-2.0, 2.0, 100)
_ = plt.plot(phi_max, d_max, '.', xp, p(xp), '-')
plt.ylim(-0.5,0.5)
(-0.5, 0.5)
plt.xlabel('phi_max before the curve')
plt.ylabel('d_max')
plt.show()

# %%
d_max_l = np.array([  0.09 , 0.09 , 0.09 , 0.03 , 0.05 , 0.13,  0.19])
phi_max_l= np.array([ 0.1 , 0.1 , 0.1, -0.2 ,-0.4 ,-0.4, -0.9])
line_l = np.polyfit(phi_max, d_max,1)
line_l
sum_phi_l=np.sum(phi_max_l)
length_phi =np.size(phi_max_l)
avg =np.average(phi_max_l)
p_l = np.poly1d(line)

xp_l = np.linspace(-2.0, 2.0, 100)
_ = plt.plot( phi_max_l,d_max_l, '.', xp_l, p(xp_l), '-')
plt.ylim(-0.5,0.5)
(-0.5, 0.5)
plt.xlabel('phi_max before the left curve with variing ranges')
plt.ylabel('d_max')
plt.show()

# %%
line_l
# Out:
# array([-0.12696246,  0.04003413])

# %%
line
# Out:
# array([-0.12696246,  0.04003413])

# %%
d_max_r = np.array([ 0.09 , -0.03, -0.03, -0.09, -0.15 , -0.09 , -0.09])

phi_max_r = np.array([ 0.1 ,0.3, 0.1 , 0.4 , 0.7, 1.4, 0.9])
line_r = np.polyfit(phi_max_r, d_max_r,1)
line_r
p_r = np.poly1d(line_r)
xp_r= np.linspace(-2.0, 2.0, 100)
_ = plt.plot(phi_max_r, d_max_r, '.', xp_r, p(xp_r), '-')
plt.ylim(-0.5,0.5)
(-0.5, 0.5)
plt.xlabel('phi_max right curve')
plt.ylabel('d_max right curve')
plt.show()

# %%
line_r
# Out:
# array([-0.09852632, -0.00082105])

# %%
line_r[0]
# Out:
# -0.09852631578947367

# %%
sum_phi_l=np.sum(phi_max_r)
if (sum_phi_l<-0.6):
    print "I see a left curve"
elif (sum_phi_l>0.6):
    print " I see a right curve"
else:
    print "I dunno"
# Out:
#  I see a right curve

# %%
avg =np.average(phi_max_l)
print avg
# Out:
# -0.228571428571

# %%
avg =np.average(phi_max_r)
print avg
# Out:
# 0.557142857143

# %%
avg =np.average(phi_max)
print avg
# Out:
# -0.528571428571

# %%
d_cur =np.average(d_max[0],d_max[1],d_max[2])
phi_cur =np.average(phi_max[0],phi_max[1],phi_max[2]) 
print "current pose phi % and d %d", phi_cur , d_cur
# Out:
#  current pose phi %d and d %d 0.1 0.07

# %%
sum_phi_l=np.sum(phi_max[3:6])
